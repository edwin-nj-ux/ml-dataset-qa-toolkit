# %% [markdown]
# # Demo: ML Dataset QA Toolkit\n\nThis notebook shows how to run the QA checks and inspect outputs.

# %%
import pandas as pd\nfrom src.io_utils import load_table\nfrom src.qa import run_qa\n\ndf, meta = load_table('../data/sample_annotations.csv')\nresults = run_qa(df, min_confidence=0.6)\nresults
